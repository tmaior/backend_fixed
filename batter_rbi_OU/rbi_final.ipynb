# %%
import pandas as pd
import unicodedata
import requests

# #send to rest API
import json 
import requests
from requests.auth import HTTPBasicAuth

# %%
under_rbi_rate=pd.read_csv('undernew.csv')
over_rbi_rate=pd.read_csv('overnew.csv')
def_rank = pd.read_csv('../scrapers/def_scraper/batter_rbi_def_rank.csv')
batter_team_2025 = pd.read_csv('../general/stats/batter_team_2025.csv')

# %%
def_rank.rename(columns={'Rank': 'def_rank'}, inplace=True)

# %%
def_rank.rename(columns={'Team': 'team'}, inplace=True)

# %%
batter_team_2025.rename(columns={'Team': 'team'}, inplace=True)

# %%
batter_team_2025.rename(columns={'Player': 'player'}, inplace=True)

# %%
team_mapping_5 = {
    'CHC': 'CHC',
    'LAD': 'LAD',
    'ARI': 'ARI',
    'PIT': 'PIT',
    'MIA': 'MIA',
    'TOR': 'TOR',
    'BOS': 'BOS',
    'ATH': 'ATH',
    'BAL': 'BAL',
    'SEA': 'SEA',
    'SDP': 'SDP',
    'ATL': 'ATL',
    'PHI': 'PHI',
    'TEX': 'TEX',
    'MIL': 'MIL',
    'WSN': 'WSH',
    'NYY': 'NYY',
    'STL': 'STL',
    'TBR': 'TBR',
    'DET': 'DET',
    'KCR': 'KCR',
    'CLE': 'CLE',
    'COL': 'COL',
    'NYM': 'NYM',
    'CIN': 'CIN',
    'MIN': 'MIN',
    'SFG': 'SFG',
    'HOU': 'HOU',
    'CHW': 'CHW',
    'LAAs': 'LAA'
}

batter_team_2025['team'] = batter_team_2025['team'].map(team_mapping_5)

# %%
team_mapping = {
    'Milwaukee Brewers': 'MIL',
    'Minnesota Twins': 'MIN',
    'Chicago Cubs': 'CHC',
    'Colorado Rockies': 'COL',
    'Washington Nationals': 'WSH',
    'Toronto Blue Jays': 'TOR',
    'Atlanta Braves': 'ATL',
    'Baltimore Orioles': 'BAL',
    'New York Yankees': 'NYY',
    'Philadelphia Phillies': 'PHI',
    'Pittsburgh Pirates': 'PIT',
    'Kansas City Royals': 'KCR',
    'Arizona Diamondbacks': 'ARI',
    'Boston Red Sox': 'BOS',
    'Detroit Tigers': 'DET',
    'Cleveland Guardians': 'CLE',
    'Tampa Bay Rays': 'TBR',
    'San Francisco Giants': 'SFG',
    'Los Angeles Dodgers': 'LAD',
    'Seattle Mariners': 'SEA',
    'Cincinnati Reds': 'CIN',
    'Texas Rangers': 'TEX',
    'Chicago White Sox': 'CHW',
    'Los Angeles Angels': 'LAA',
    'Miami Marlins': 'MIA',
    'New York Mets': 'NYM',
    'Athletics': 'ATH',
    'St. Louis Cardinals': 'STL',
    'San Diego Padres': 'SDP',
    'Houston Astros': 'HOU'
}

def_rank['team'] = def_rank['team'].map(team_mapping)

# %%
#fixing the accentes on the names
def normalize_name(name):
    if not isinstance(name, str):
        return name
    return unicodedata.normalize('NFKD', name).encode('ascii', 'ignore').decode('utf-8')

# %%
batter_team_2025['player'] = batter_team_2025['player'].apply(normalize_name)

# %%
#cleaning the # and *
def clean_name_symbols(name):
    if not isinstance(name, str):
        return name
    return name.replace('*', '').replace('#', '')

batter_team_2025['player'] = batter_team_2025['player'].apply(clean_name_symbols)

# %%
# multi_team_flags = ['2TM', '3TM', '4TM', '5TM']
# filtered_df_2 = batter_team_2025[~batter_team_2025['team'].isin(multi_team_flags)].copy()


# # Step 2: Keep only the LAST team listed for each player (i.e., current team)
# batter_team_2025 = filtered_df_2.drop_duplicates(subset='player', keep='last').reset_index(drop=True)

# %%
# Set API Key
headers = {
    'X-Api-Key': 'fac7e1a69f2baa47da395bde36dc869c'  # Ensure this is correct
}

# API URL
url = 'https://api.sportsgameodds.com/v2/events/'

next_cursor = None
event_data = []

# Fetch only Over/Under odds for rbi across all players
while True:
    try:
        response = requests.get(
            url,
            headers=headers,
            params={
                "sportID":"BASEBALL",
                "leagueID": "MLB",
                "oddIDs": "batting_RBI-PLAYER_ID-game-ou-over",
                "includeOpposingOddIDs": "true", 
                "oddsAvailable":"true",
                "cursor": next_cursor,
                "include":"teams",
                'started':"false",

            },
        )

        response.raise_for_status()  # Raise an error if the request fails

        data = response.json()
        event_data.extend(data.get("data", []))
        next_cursor = data.get("nextCursor")

        if not next_cursor:
            break

    except requests.exceptions.RequestException as e:
        print("Error fetching events:", e)
        break

# %%
event_data
# Out:
# [{'eventID': 'cDWGktUsQQXA4NRluc0P',
#   'sportID': 'BASEBALL',
#   'leagueID': 'MLB',
#   'type': 'match',
#   'teams': {'home': {'teamID': 'NEW_YORK_YANKEES_MLB',
#     'names': {'long': 'New York Yankees', 'short': 'NYY', 'medium': 'Yankees'},
#     'colors': {'primary': '#000066', 'primaryContrast': '#FFFFFF'},
#     'statEntityID': 'home'},
#    'away': {'teamID': 'NEW_YORK_METS_MLB',
#     'names': {'long': 'New York Mets', 'short': 'NYM', 'medium': 'Mets'},
#     'colors': {'primary': '#032D75', 'primaryContrast': '#FFFFFF'},
#     'statEntityID': 'away'}},
#   'odds': {'batting_RBI-AARON_JUDGE_1_MLB-game-ou-over': {'oddID': 'batting_RBI-AARON_JUDGE_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-AARON_JUDGE_1_MLB-game-ou-under',
#     'marketName': 'Aaron Judge Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'AARON_JUDGE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'AARON_JUDGE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '+112',
#     'bookOdds': '-105',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+112',
#     'openBookOdds': '-105',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-105',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+100',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+100',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-105',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '-120',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '-120',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '-121',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '-121',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+105',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-AARON_JUDGE_1_MLB-game-ou-under': {'oddID': 'batting_RBI-AARON_JUDGE_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-AARON_JUDGE_1_MLB-game-ou-over',
#     'marketName': 'Aaron Judge Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'AARON_JUDGE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'AARON_JUDGE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-112',
#     'bookOdds': '-135',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-112',
#     'openBookOdds': '-135',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-135',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-135',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-135',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-135',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-PETE_ALONSO_1_MLB-game-ou-over': {'oddID': 'batting_RBI-PETE_ALONSO_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-PETE_ALONSO_1_MLB-game-ou-under',
#     'marketName': 'Pete Alonso Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'PETE_ALONSO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'PETE_ALONSO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '+135',
#     'bookOdds': '+117',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+135',
#     'openBookOdds': '+117',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+120',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+120',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+125',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+110',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+110',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+115',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+117',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+117',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+125',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-PETE_ALONSO_1_MLB-game-ou-under': {'oddID': 'batting_RBI-PETE_ALONSO_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-PETE_ALONSO_1_MLB-game-ou-over',
#     'marketName': 'Pete Alonso Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'PETE_ALONSO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'PETE_ALONSO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-135',
#     'bookOdds': '-165',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-135',
#     'openBookOdds': '-165',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-PAUL_GOLDSCHMIDT_1_MLB-game-ou-over': {'oddID': 'batting_RBI-PAUL_GOLDSCHMIDT_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-PAUL_GOLDSCHMIDT_1_MLB-game-ou-under',
#     'marketName': 'Paul Goldschmidt Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'PAUL_GOLDSCHMIDT_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'PAUL_GOLDSCHMIDT_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '+146',
#     'bookOdds': '+130',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+146',
#     'openBookOdds': '+130',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+125',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+125',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+125',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-PAUL_GOLDSCHMIDT_1_MLB-game-ou-under': {'oddID': 'batting_RBI-PAUL_GOLDSCHMIDT_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-PAUL_GOLDSCHMIDT_1_MLB-game-ou-over',
#     'marketName': 'Paul Goldschmidt Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'PAUL_GOLDSCHMIDT_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'PAUL_GOLDSCHMIDT_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-146',
#     'bookOdds': '-175',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-146',
#     'openBookOdds': '-175',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-170',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-180',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-BENJAMIN_RICE_1_MLB-game-ou-over': {'oddID': 'batting_RBI-BENJAMIN_RICE_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-BENJAMIN_RICE_1_MLB-game-ou-under',
#     'marketName': 'Ben Rice Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'BENJAMIN_RICE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'BENJAMIN_RICE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+169',
#     'bookOdds': '+160',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+169',
#     'openBookOdds': '+160',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+170',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+145',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+145',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-BENJAMIN_RICE_1_MLB-game-ou-under': {'oddID': 'batting_RBI-BENJAMIN_RICE_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-BENJAMIN_RICE_1_MLB-game-ou-over',
#     'marketName': 'Ben Rice Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'BENJAMIN_RICE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'BENJAMIN_RICE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-169',
#     'bookOdds': '-240',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-169',
#     'openBookOdds': '-240',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-240',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-240',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-240',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-235',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-BRANDON_NIMMO_1_MLB-game-ou-over': {'oddID': 'batting_RBI-BRANDON_NIMMO_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-BRANDON_NIMMO_1_MLB-game-ou-under',
#     'marketName': 'Brandon Nimmo Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'BRANDON_NIMMO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'BRANDON_NIMMO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+165',
#     'bookOdds': '+140',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+165',
#     'openBookOdds': '+140',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+145',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+135',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+148',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+148',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-BRANDON_NIMMO_1_MLB-game-ou-under': {'oddID': 'batting_RBI-BRANDON_NIMMO_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-BRANDON_NIMMO_1_MLB-game-ou-over',
#     'marketName': 'Brandon Nimmo Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'BRANDON_NIMMO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'BRANDON_NIMMO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-165',
#     'bookOdds': '-200',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-165',
#     'openBookOdds': '-200',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-205',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-AUSTIN_WELLS_1_MLB-game-ou-over': {'oddID': 'batting_RBI-AUSTIN_WELLS_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-AUSTIN_WELLS_1_MLB-game-ou-under',
#     'marketName': 'Austin Wells Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'AUSTIN_WELLS_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'AUSTIN_WELLS_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '+173',
#     'bookOdds': '+150',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+173',
#     'openBookOdds': '+150',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+145',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:13.000Z',
#       'available': False},
#      'espnbet': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:01.000Z',
#       'available': False},
#      'hardrockbet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False},
#      'fliff': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:12:01.000Z',
#       'available': False},
#      'fanduel': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:54.000Z',
#       'available': False},
#      'fanatics': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:33:41.000Z',
#       'available': False},
#      'ballybet': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:08:43.000Z',
#       'available': False},
#      'betrivers': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:08:32.000Z',
#       'available': False},
#      'betmgm': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False}}},
#    'batting_RBI-AUSTIN_WELLS_1_MLB-game-ou-under': {'oddID': 'batting_RBI-AUSTIN_WELLS_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-AUSTIN_WELLS_1_MLB-game-ou-over',
#     'marketName': 'Austin Wells Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'AUSTIN_WELLS_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'AUSTIN_WELLS_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '-173',
#     'bookOdds': '-200',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-173',
#     'openBookOdds': '-200',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-205',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:13.000Z',
#       'available': False},
#      'espnbet': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:01.000Z',
#       'available': False},
#      'hardrockbet': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False},
#      'fliff': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:12:01.000Z',
#       'available': False},
#      'betmgm': {'odds': '-200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False}}},
#    'batting_RBI-JUAN_SOTO_1_MLB-game-ou-over': {'oddID': 'batting_RBI-JUAN_SOTO_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-JUAN_SOTO_1_MLB-game-ou-under',
#     'marketName': 'Juan Soto Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'JUAN_SOTO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'JUAN_SOTO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+172',
#     'bookOdds': '+150',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+172',
#     'openBookOdds': '+150',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+145',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+130',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-JUAN_SOTO_1_MLB-game-ou-under': {'oddID': 'batting_RBI-JUAN_SOTO_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-JUAN_SOTO_1_MLB-game-ou-over',
#     'marketName': 'Juan Soto Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'JUAN_SOTO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'JUAN_SOTO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-172',
#     'bookOdds': '-215',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-172',
#     'openBookOdds': '-215',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-215',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-215',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-CODY_BELLINGER_1_MLB-game-ou-over': {'oddID': 'batting_RBI-CODY_BELLINGER_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-CODY_BELLINGER_1_MLB-game-ou-under',
#     'marketName': 'Cody Bellinger Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'CODY_BELLINGER_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'CODY_BELLINGER_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+177',
#     'bookOdds': '+150',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+177',
#     'openBookOdds': '+150',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+145',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-CODY_BELLINGER_1_MLB-game-ou-under': {'oddID': 'batting_RBI-CODY_BELLINGER_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-CODY_BELLINGER_1_MLB-game-ou-over',
#     'marketName': 'Cody Bellinger Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'CODY_BELLINGER_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'CODY_BELLINGER_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-177',
#     'bookOdds': '-220',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-177',
#     'openBookOdds': '-220',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-225',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-215',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-MARK_VIENTOS_1_MLB-game-ou-over': {'oddID': 'batting_RBI-MARK_VIENTOS_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-MARK_VIENTOS_1_MLB-game-ou-under',
#     'marketName': 'Mark Vientos Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'MARK_VIENTOS_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'MARK_VIENTOS_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+182',
#     'bookOdds': '+150',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+182',
#     'openBookOdds': '+150',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+155',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+140',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-MARK_VIENTOS_1_MLB-game-ou-under': {'oddID': 'batting_RBI-MARK_VIENTOS_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-MARK_VIENTOS_1_MLB-game-ou-over',
#     'marketName': 'Mark Vientos Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'MARK_VIENTOS_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'MARK_VIENTOS_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-182',
#     'bookOdds': '-220',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-182',
#     'openBookOdds': '-220',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-230',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-FRANCISCO_LINDOR_1_MLB-game-ou-over': {'oddID': 'batting_RBI-FRANCISCO_LINDOR_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-FRANCISCO_LINDOR_1_MLB-game-ou-under',
#     'marketName': 'Francisco Lindor Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'FRANCISCO_LINDOR_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'FRANCISCO_LINDOR_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+179',
#     'bookOdds': '+160',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+179',
#     'openBookOdds': '+160',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+160',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+150',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+170',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-FRANCISCO_LINDOR_1_MLB-game-ou-under': {'oddID': 'batting_RBI-FRANCISCO_LINDOR_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-FRANCISCO_LINDOR_1_MLB-game-ou-over',
#     'marketName': 'Francisco Lindor Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'FRANCISCO_LINDOR_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'FRANCISCO_LINDOR_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-179',
#     'bookOdds': '-225',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-179',
#     'openBookOdds': '-225',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-240',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-225',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-225',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-235',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-TRENT_GRISHAM_1_MLB-game-ou-over': {'oddID': 'batting_RBI-TRENT_GRISHAM_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-TRENT_GRISHAM_1_MLB-game-ou-under',
#     'marketName': 'Trent Grisham Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'TRENT_GRISHAM_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'TRENT_GRISHAM_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '+202',
#     'bookOdds': '+175',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+202',
#     'openBookOdds': '+175',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:13.000Z',
#       'available': False},
#      'espnbet': {'odds': '+165',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:01.000Z',
#       'available': False},
#      'hardrockbet': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False},
#      'fliff': {'odds': '+180',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:12:01.000Z',
#       'available': False},
#      'fanduel': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:54.000Z',
#       'available': False},
#      'fanatics': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:33:41.000Z',
#       'available': False},
#      'ballybet': {'odds': '+185',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:08:43.000Z',
#       'available': False},
#      'betrivers': {'odds': '+185',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:08:32.000Z',
#       'available': False},
#      'betmgm': {'odds': '+180',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False}}},
#    'batting_RBI-TRENT_GRISHAM_1_MLB-game-ou-under': {'oddID': 'batting_RBI-TRENT_GRISHAM_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-TRENT_GRISHAM_1_MLB-game-ou-over',
#     'marketName': 'Trent Grisham Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'TRENT_GRISHAM_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'TRENT_GRISHAM_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '-202',
#     'bookOdds': '-240',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-202',
#     'openBookOdds': '-240',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-250',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:13.000Z',
#       'available': False},
#      'espnbet': {'odds': '-240',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:01.000Z',
#       'available': False},
#      'hardrockbet': {'odds': '-240',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False},
#      'fliff': {'odds': '-270',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:12:01.000Z',
#       'available': False},
#      'betmgm': {'odds': '-235',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False}}},
#    'batting_RBI-ANTHONY_VOLPE_1_MLB-game-ou-over': {'oddID': 'batting_RBI-ANTHONY_VOLPE_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-ANTHONY_VOLPE_1_MLB-game-ou-under',
#     'marketName': 'Anthony Volpe Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'ANTHONY_VOLPE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'ANTHONY_VOLPE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '+213',
#     'bookOdds': '+175',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+213',
#     'openBookOdds': '+175',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+180',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+180',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+190',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+175',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+170',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+170',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+185',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-ANTHONY_VOLPE_1_MLB-game-ou-under': {'oddID': 'batting_RBI-ANTHONY_VOLPE_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-ANTHONY_VOLPE_1_MLB-game-ou-over',
#     'marketName': 'Anthony Volpe Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'ANTHONY_VOLPE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'ANTHONY_VOLPE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-213',
#     'bookOdds': '-250',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-213',
#     'openBookOdds': '-250',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-260',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-250',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-250',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-285',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-250',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-JEFF_MCNEIL_1_MLB-game-ou-over': {'oddID': 'batting_RBI-JEFF_MCNEIL_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-JEFF_MCNEIL_1_MLB-game-ou-under',
#     'marketName': 'Jeff McNeil Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'JEFF_MCNEIL_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'JEFF_MCNEIL_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '+241',
#     'bookOdds': '+215',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+241',
#     'openBookOdds': '+215',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+225',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '+215',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '+225',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '+210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'fanduel': {'odds': '+195',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:59.000Z',
#       'available': True},
#      'fanatics': {'odds': '+225',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:01.000Z',
#       'available': True},
#      'ballybet': {'odds': '+200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:56.000Z',
#       'available': True},
#      'betrivers': {'odds': '+200',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '+230',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-JEFF_MCNEIL_1_MLB-game-ou-under': {'oddID': 'batting_RBI-JEFF_MCNEIL_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-JEFF_MCNEIL_1_MLB-game-ou-over',
#     'marketName': 'Jeff McNeil Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'JEFF_MCNEIL_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'JEFF_MCNEIL_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-241',
#     'bookOdds': '-325',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-241',
#     'openBookOdds': '-325',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '-330',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:42.000Z',
#       'available': True},
#      'espnbet': {'odds': '-350',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:09.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-325',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:38:55.000Z',
#       'available': True},
#      'fliff': {'odds': '-320',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:34.000Z',
#       'available': True},
#      'betmgm': {'odds': '-325',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:31.000Z',
#       'available': True}}},
#    'batting_RBI-OSWALD_PERAZA_1_MLB-game-ou-over': {'oddID': 'batting_RBI-OSWALD_PERAZA_1_MLB-game-ou-over',
#     'opposingOddID': 'batting_RBI-OSWALD_PERAZA_1_MLB-game-ou-under',
#     'marketName': 'Oswald Peraza Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'OSWALD_PERAZA_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'over',
#     'playerID': 'OSWALD_PERAZA_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '+237',
#     'bookOdds': '+212',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '+237',
#     'openBookOdds': '+212',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'draftkings': {'odds': '+215',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:13.000Z',
#       'available': False},
#      'espnbet': {'odds': '+210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:01.000Z',
#       'available': False},
#      'hardrockbet': {'odds': '+220',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:43.000Z',
#       'available': False},
#      'fliff': {'odds': '+215',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:12:01.000Z',
#       'available': False},
#      'fanduel': {'odds': '+210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:05:54.000Z',
#       'available': False},
#      'fanatics': {'odds': '+210',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T14:33:41.000Z',
#       'available': False}}},
#    'batting_RBI-OSWALD_PERAZA_1_MLB-game-ou-under': {'oddID': 'batting_RBI-OSWALD_PERAZA_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-OSWALD_PERAZA_1_MLB-game-ou-over',
#     'marketName': 'Oswald Peraza Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'OSWALD_PERAZA_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'OSWALD_PERAZA_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '-237',
#     'bookOdds': '-317',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
# ...
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-525',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-510',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-500',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True},
#      'betmgm': {'odds': '-525',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:43.000Z',
#       'available': True}}},
#    'batting_RBI-MIGUEL_ROJAS_1_MLB-game-ou-under': {'oddID': 'batting_RBI-MIGUEL_ROJAS_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-MIGUEL_ROJAS_1_MLB-game-ou-over',
#     'marketName': 'Miguel Rojas Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'MIGUEL_ROJAS_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'MIGUEL_ROJAS_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-253',
#     'bookOdds': '-340',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-253',
#     'openBookOdds': '-340',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'espnbet': {'odds': '-375',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-330',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-350',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-325',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True}}},
#    'batting_RBI-LUIS_RENGIFO_1_MLB-game-ou-under': {'oddID': 'batting_RBI-LUIS_RENGIFO_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-LUIS_RENGIFO_1_MLB-game-ou-over',
#     'marketName': 'Luis Rengifo Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'LUIS_RENGIFO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'LUIS_RENGIFO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-296',
#     'bookOdds': '-400',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-296',
#     'openBookOdds': '-400',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'espnbet': {'odds': '-450',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-400',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-410',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-400',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True},
#      'betmgm': {'odds': '-400',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:43.000Z',
#       'available': True}}},
#    'batting_RBI-LOGAN_OHOPPE_1_MLB-game-ou-under': {'oddID': 'batting_RBI-LOGAN_OHOPPE_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-LOGAN_OHOPPE_1_MLB-game-ou-over',
#     'marketName': "Logan O'Hoppe Runs Batted In Over/Under",
#     'statID': 'batting_RBI',
#     'statEntityID': 'LOGAN_OHOPPE_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'LOGAN_OHOPPE_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-234',
#     'bookOdds': '-310',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-234',
#     'openBookOdds': '-310',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'espnbet': {'odds': '-325',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-310',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-280',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-325',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True},
#      'betmgm': {'odds': '-300',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:43.000Z',
#       'available': True}}},
#    'batting_RBI-KEVIN_NEWMAN_1_MLB-game-ou-under': {'oddID': 'batting_RBI-KEVIN_NEWMAN_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-KEVIN_NEWMAN_1_MLB-game-ou-over',
#     'marketName': 'Kevin Newman Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'KEVIN_NEWMAN_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'KEVIN_NEWMAN_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-350',
#     'bookOdds': '-500',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-350',
#     'openBookOdds': '-500',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'espnbet': {'odds': '-550',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-500',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-490',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-500',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True},
#      'betmgm': {'odds': '-500',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:43.000Z',
#       'available': True}}},
#    'batting_RBI-MICHAEL_CONFORTO_1_MLB-game-ou-under': {'oddID': 'batting_RBI-MICHAEL_CONFORTO_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-MICHAEL_CONFORTO_1_MLB-game-ou-over',
#     'marketName': 'Michael Conforto Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'MICHAEL_CONFORTO_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'MICHAEL_CONFORTO_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': False,
#     'fairOdds': '-225',
#     'bookOdds': '-300',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-225',
#     'openBookOdds': '-300',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'espnbet': {'odds': '-300',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-300',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-315',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-275',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True},
#      'betmgm': {'odds': '-275',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:43.000Z',
#       'available': True}}},
#    'batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under': {'oddID': 'batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-over',
#     'marketName': 'Chris Taylor Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'CHRIS_TAYLOR_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'CHRIS_TAYLOR_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': True,
#     'fairOddsAvailable': True,
#     'fairOdds': '-296',
#     'bookOdds': '-400',
#     'fairOverUnder': '0.5',
#     'bookOverUnder': '0.5',
#     'openFairOdds': '-296',
#     'openBookOdds': '-400',
#     'openFairOverUnder': '0.5',
#     'openBookOverUnder': '0.5',
#     'scoringSupported': True,
#     'byBookmaker': {'espnbet': {'odds': '-425',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:08.000Z',
#       'available': True},
#      'draftkings': {'odds': '-390',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:07.000Z',
#       'available': True},
#      'fliff': {'odds': '-400',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:18.000Z',
#       'available': True},
#      'hardrockbet': {'odds': '-400',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:14.000Z',
#       'available': True},
#      'betmgm': {'odds': '-375',
#       'overUnder': '0.5',
#       'lastUpdatedAt': '2025-05-17T16:39:43.000Z',
#       'available': True}}},
#    'batting_RBI-YOAN_MONCADA_1_MLB-game-ou-under': {'oddID': 'batting_RBI-YOAN_MONCADA_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-YOAN_MONCADA_1_MLB-game-ou-over',
#     'marketName': 'Yoan Moncada Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'YOAN_MONCADA_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'YOAN_MONCADA_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '-880',
#     'openFairOdds': '-880',
#     'scoringSupported': True},
#    'batting_RBI-JO_ADELL_1_MLB-game-ou-under': {'oddID': 'batting_RBI-JO_ADELL_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-JO_ADELL_1_MLB-game-ou-over',
#     'marketName': 'Jo Adell Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'JO_ADELL_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'JO_ADELL_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': True,
#     'fairOdds': '-880',
#     'fairOverUnder': '1.5',
#     'openFairOdds': '-880',
#     'openFairOverUnder': '1.5',
#     'scoringSupported': True},
#    'batting_RBI-KYREN_PARIS_1_MLB-game-ou-under': {'oddID': 'batting_RBI-KYREN_PARIS_1_MLB-game-ou-under',
#     'opposingOddID': 'batting_RBI-KYREN_PARIS_1_MLB-game-ou-over',
#     'marketName': 'Kyren Paris Runs Batted In Over/Under',
#     'statID': 'batting_RBI',
#     'statEntityID': 'KYREN_PARIS_1_MLB',
#     'periodID': 'game',
#     'betTypeID': 'ou',
#     'sideID': 'under',
#     'playerID': 'KYREN_PARIS_1_MLB',
#     'started': False,
#     'ended': False,
#     'cancelled': False,
#     'bookOddsAvailable': False,
#     'fairOddsAvailable': False,
#     'fairOdds': '-1045',
#     'openFairOdds': '-1045',
#     'scoringSupported': True}},
#   'status': {'started': False,
#    'completed': False,
#    'cancelled': False,
#    'ended': False,
#    'live': False,
#    'delayed': False,
#    'displayLong': 'Upcoming',
#    'hardStart': True,
#    'finalized': False,
#    'currentPeriodID': '',
#    'previousPeriodID': '',
#    'displayShort': '',
#    'oddsPresent': True,
#    'oddsAvailable': True,
#    'inBreak': False,
#    'periods': {'started': [], 'ended': []},
#    'startsAt': '2025-05-18T01:10:00.000Z',
#    'previousStartsAt': ['2025-05-17T20:00:00.000Z']},
#   'players': {'TAYLOR_WARD_1_MLB': {'playerID': 'TAYLOR_WARD_1_MLB',
#     'firstName': 'Joseph',
#     'lastName': 'Ward',
#     'name': 'Taylor Ward',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'FREDDIE_FREEMAN_1_MLB': {'playerID': 'FREDDIE_FREEMAN_1_MLB',
#     'firstName': 'Frederick',
#     'lastName': 'Freeman',
#     'name': 'Freddie Freeman',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'WILL_SMITH_2_MLB': {'playerID': 'WILL_SMITH_2_MLB',
#     'firstName': 'William',
#     'lastName': 'Smith',
#     'name': 'Will Smith',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'MOOKIE_BETTS_1_MLB': {'playerID': 'MOOKIE_BETTS_1_MLB',
#     'firstName': 'Markus',
#     'lastName': 'Betts',
#     'name': 'Mookie Betts',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'JO_ADELL_1_MLB': {'playerID': 'JO_ADELL_1_MLB',
#     'firstName': 'Jordon',
#     'lastName': 'Adell',
#     'name': 'Jo Adell',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'LUIS_RENGIFO_1_MLB': {'playerID': 'LUIS_RENGIFO_1_MLB',
#     'firstName': 'Luis',
#     'lastName': 'Rengifo',
#     'name': 'Luis Rengifo',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'CHRIS_TAYLOR_1_MLB': {'playerID': 'CHRIS_TAYLOR_1_MLB',
#     'firstName': 'Christopher',
#     'lastName': 'Taylor',
#     'name': 'Chris Taylor',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'MIGUEL_ROJAS_1_MLB': {'playerID': 'MIGUEL_ROJAS_1_MLB',
#     'firstName': 'Miguel',
#     'lastName': 'Rojas',
#     'name': 'Miguel Rojas',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'LOGAN_OHOPPE_1_MLB': {'playerID': 'LOGAN_OHOPPE_1_MLB',
#     'firstName': 'Logan',
#     'lastName': "O'Hoppe",
#     'name': "Logan O'Hoppe",
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'ANDY_PAGES_1_MLB': {'playerID': 'ANDY_PAGES_1_MLB',
#     'firstName': 'Andy',
#     'lastName': 'Pages',
#     'name': 'Andy Pages',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'ENRIQUE_HERNANDEZ_1_MLB': {'playerID': 'ENRIQUE_HERNANDEZ_1_MLB',
#     'firstName': 'Enrique',
#     'lastName': 'Hernandez',
#     'name': 'Kike Hernandez',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'NOLAN_SCHANUEL_1_MLB': {'playerID': 'NOLAN_SCHANUEL_1_MLB',
#     'firstName': 'Nolan',
#     'lastName': 'Schanuel',
#     'name': 'Nolan Schanuel',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'SHOHEI_OHTANI_1_MLB': {'playerID': 'SHOHEI_OHTANI_1_MLB',
#     'firstName': 'Shohei',
#     'lastName': 'Ohtani',
#     'name': 'Shohei Ohtani',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'MICHAEL_CONFORTO_1_MLB': {'playerID': 'MICHAEL_CONFORTO_1_MLB',
#     'firstName': 'Michael',
#     'lastName': 'Conforto',
#     'name': 'Michael Conforto',
#     'teamID': 'LOS_ANGELES_DODGERS_MLB'},
#    'JORGE_SOLER_1_MLB': {'playerID': 'JORGE_SOLER_1_MLB',
#     'firstName': 'Jorge',
#     'lastName': 'Soler',
#     'name': 'Jorge Soler',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'YOAN_MONCADA_1_MLB': {'playerID': 'YOAN_MONCADA_1_MLB',
#     'firstName': 'Yoan',
#     'lastName': 'Moncada',
#     'name': 'Yoan Moncada',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'TRAVIS_DARNAUD_1_MLB': {'playerID': 'TRAVIS_DARNAUD_1_MLB',
#     'firstName': 'Travis',
#     'lastName': "d'Arnaud",
#     'name': "Travis d'Arnaud",
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'TYLER_ANDERSON_1_MLB': {'playerID': 'TYLER_ANDERSON_1_MLB',
#     'firstName': 'Tyler',
#     'lastName': 'Anderson',
#     'name': 'Tyler Anderson',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'KYREN_PARIS_1_MLB': {'playerID': 'KYREN_PARIS_1_MLB',
#     'firstName': 'Kyren',
#     'lastName': 'Paris',
#     'name': 'Kyren Paris',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'ZACHARY_NETO_1_MLB': {'playerID': 'ZACHARY_NETO_1_MLB',
#     'firstName': 'Zachary',
#     'lastName': 'Neto',
#     'name': 'Zachary Neto',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'TIMOTHY_ANDERSON_1_MLB': {'playerID': 'TIMOTHY_ANDERSON_1_MLB',
#     'firstName': 'Timothy',
#     'lastName': 'Anderson',
#     'name': 'Tim Anderson',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'},
#    'KEVIN_NEWMAN_1_MLB': {'playerID': 'KEVIN_NEWMAN_1_MLB',
#     'firstName': 'Kevin',
#     'lastName': 'Newman',
#     'name': 'Kevin Newman',
#     'teamID': 'LOS_ANGELES_ANGELS_MLB'}},
#   'results': {},
#   'info': {'seasonWeek': 'MLB 2025'}}]

# %%
# Initialize an empty list for structured data
odds_list = []

for event in event_data:
    event_id = event.get("eventID", "Unknown Event")
    teams = sorted(set(player_data.get("teamID") for player_data in event.get("players", {}).values() if player_data.get("teamID")))
    
    odds = event.get("odds", {})
    
    for odd_id, odd_object in odds.items():
        base_row = {
            "eventID": event_id,
            "teams": ", ".join(teams),
            "oddID": odd_object.get("oddID"),
            "opposingOddID": odd_object.get("opposingOddID"),
            "marketName": odd_object.get("marketName"),
            "playerID": odd_object.get("statEntityID"),
            "side": odd_object.get("sideID"),
            "line": odd_object.get("bookOverUnder", odd_object.get("fairOverUnder", "N/A")),
            "score": odd_object.get("score", "N/A"),
        }
        
        # Extract bookmaker-specific odds into separate rows
        by_bookmaker = odd_object.get("byBookmaker", {})
        
        for bookmaker, book_data in by_bookmaker.items():
            row = base_row.copy()
            row["bookmaker"] = bookmaker
            row["odds"] = book_data.get("odds", "N/A")
            row["overUnder"] = book_data.get("overUnder", "N/A")
            odds_list.append(row)

# Convert to Pandas DataFrame
df_odds = pd.DataFrame(odds_list)

# Print the DataFrame
df_odds.head(5)
# Out:
#                 eventID                                    teams  \
# 0  cDWGktUsQQXA4NRluc0P  NEW_YORK_METS_MLB, NEW_YORK_YANKEES_MLB
# 1  cDWGktUsQQXA4NRluc0P  NEW_YORK_METS_MLB, NEW_YORK_YANKEES_MLB
# 2  cDWGktUsQQXA4NRluc0P  NEW_YORK_METS_MLB, NEW_YORK_YANKEES_MLB
# 3  cDWGktUsQQXA4NRluc0P  NEW_YORK_METS_MLB, NEW_YORK_YANKEES_MLB
# 4  cDWGktUsQQXA4NRluc0P  NEW_YORK_METS_MLB, NEW_YORK_YANKEES_MLB
#
#                                         oddID  \
# 0  batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 1  batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 2  batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 3  batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 4  batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
#
#                                  opposingOddID  \
# 0  batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 1  batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 2  batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 3  batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 4  batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
#
#                               marketName           playerID  side line score  \
# 0  Aaron Judge Runs Batted In Over/Under  AARON_JUDGE_1_MLB  over  0.5   N/A
# 1  Aaron Judge Runs Batted In Over/Under  AARON_JUDGE_1_MLB  over  0.5   N/A
# 2  Aaron Judge Runs Batted In Over/Under  AARON_JUDGE_1_MLB  over  0.5   N/A
# 3  Aaron Judge Runs Batted In Over/Under  AARON_JUDGE_1_MLB  over  0.5   N/A
# 4  Aaron Judge Runs Batted In Over/Under  AARON_JUDGE_1_MLB  over  0.5   N/A
#
#      bookmaker  odds overUnder
# 0   draftkings  -105       0.5
# 1      espnbet  +100       0.5
# 2  hardrockbet  +100       0.5
# 3        fliff  -105       0.5
# 4      fanduel  -120       0.5

# %%
df_odds['bookmaker'].unique()
# Out:
# array(['draftkings', 'espnbet', 'hardrockbet', 'fliff', 'fanduel',
#        'fanatics', 'ballybet', 'betrivers', 'betmgm', 'prizepicks'],
#       dtype=object)

# %%
#getting the last 3 letters of the teams collumn to get MLB
df_odds['sport'] = df_odds['teams'].str[-3:]

# %%
# Split into two new columns
df_odds[['team_1', 'team_2']] = df_odds['teams'].str.split(', ', expand=True)
# Remove the "_MLB" suffix from both columns using .loc
df_odds.loc[:, 'team_1'] = df_odds['team_1'].str.replace('_MLB', '', regex=False)
df_odds.loc[:, 'team_2'] = df_odds['team_2'].str.replace('_MLB', '', regex=False)
# Drop the original 'teams' column
df_odds = df_odds.drop(columns=['teams'])

# %%
df_odds
# Out:
#                    eventID                                         oddID  \
# 0     cDWGktUsQQXA4NRluc0P    batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 1     cDWGktUsQQXA4NRluc0P    batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 2     cDWGktUsQQXA4NRluc0P    batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 3     cDWGktUsQQXA4NRluc0P    batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# 4     cDWGktUsQQXA4NRluc0P    batting_RBI-AARON_JUDGE_1_MLB-game-ou-over
# ...                    ...                                           ...
# 3675  nF4FjrcX6JlEKRRvN7AT  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under
# 3676  nF4FjrcX6JlEKRRvN7AT  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under
# 3677  nF4FjrcX6JlEKRRvN7AT  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under
# 3678  nF4FjrcX6JlEKRRvN7AT  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under
# 3679  nF4FjrcX6JlEKRRvN7AT  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-under
#
#                                     opposingOddID  \
# 0     batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 1     batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 2     batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 3     batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# 4     batting_RBI-AARON_JUDGE_1_MLB-game-ou-under
# ...                                           ...
# 3675  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-over
# 3676  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-over
# 3677  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-over
# 3678  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-over
# 3679  batting_RBI-CHRIS_TAYLOR_1_MLB-game-ou-over
#
#                                   marketName            playerID   side line  \
# 0      Aaron Judge Runs Batted In Over/Under   AARON_JUDGE_1_MLB   over  0.5
# 1      Aaron Judge Runs Batted In Over/Under   AARON_JUDGE_1_MLB   over  0.5
# 2      Aaron Judge Runs Batted In Over/Under   AARON_JUDGE_1_MLB   over  0.5
# 3      Aaron Judge Runs Batted In Over/Under   AARON_JUDGE_1_MLB   over  0.5
# 4      Aaron Judge Runs Batted In Over/Under   AARON_JUDGE_1_MLB   over  0.5
# ...                                      ...                 ...    ...  ...
# 3675  Chris Taylor Runs Batted In Over/Under  CHRIS_TAYLOR_1_MLB  under  0.5
# 3676  Chris Taylor Runs Batted In Over/Under  CHRIS_TAYLOR_1_MLB  under  0.5
# 3677  Chris Taylor Runs Batted In Over/Under  CHRIS_TAYLOR_1_MLB  under  0.5
# 3678  Chris Taylor Runs Batted In Over/Under  CHRIS_TAYLOR_1_MLB  under  0.5
# 3679  Chris Taylor Runs Batted In Over/Under  CHRIS_TAYLOR_1_MLB  under  0.5
#
#      score    bookmaker  odds overUnder sport              team_1  \
# 0      N/A   draftkings  -105       0.5   MLB       NEW_YORK_METS
# 1      N/A      espnbet  +100       0.5   MLB       NEW_YORK_METS
# 2      N/A  hardrockbet  +100       0.5   MLB       NEW_YORK_METS
# 3      N/A        fliff  -105       0.5   MLB       NEW_YORK_METS
# 4      N/A      fanduel  -120       0.5   MLB       NEW_YORK_METS
# ...    ...          ...   ...       ...   ...                 ...
# 3675   N/A      espnbet  -425       0.5   MLB  LOS_ANGELES_ANGELS
# 3676   N/A   draftkings  -390       0.5   MLB  LOS_ANGELES_ANGELS
# 3677   N/A        fliff  -400       0.5   MLB  LOS_ANGELES_ANGELS
# 3678   N/A  hardrockbet  -400       0.5   MLB  LOS_ANGELES_ANGELS
# 3679   N/A       betmgm  -375       0.5   MLB  LOS_ANGELES_ANGELS
#
#                    team_2
# 0        NEW_YORK_YANKEES
# 1        NEW_YORK_YANKEES
# 2        NEW_YORK_YANKEES
# 3        NEW_YORK_YANKEES
# 4        NEW_YORK_YANKEES
# ...                   ...
# 3675  LOS_ANGELES_DODGERS
# 3676  LOS_ANGELES_DODGERS
# 3677  LOS_ANGELES_DODGERS
# 3678  LOS_ANGELES_DODGERS
# 3679  LOS_ANGELES_DODGERS
#
# [3680 rows x 14 columns]

# %%
#extract the players name from marketName
df_odds['player'] = df_odds['marketName'].str.extract(r'^(.*?)\s*Runs')

# %%
# Define the mapping dictionary
team_mapping = {
    'ARIZONA_DIAMONDBACKS': 'ARI',
    'ATLANTA_BRAVES': 'ATL',
    'BALTIMORE_ORIOLES': 'BAL',
    'BOSTON_RED_SOX': 'BOS',
    'CHICAGO_CUBS': 'CHC',
    'CHICAGO_WHITE_SOX': 'CHW',
    'CINCINNATI_REDS': 'CIN',
    'CLEVELAND_GUARDIANS': 'CLE',
    'COLORADO_ROCKIES': 'COL',
    'DETROIT_TIGERS': 'DET',
    'HOUSTON_ASTROS': 'HOU',
    'KANSAS_CITY_ROYALS': 'KCR',
    'LOS_ANGELES_ANGELS': 'LAA',
    'LOS_ANGELES_DODGERS': 'LAD',
    'MIAMI_MARLINS': 'MIA',
    'MILWAUKEE_BREWERS': 'MIL',
    'MINNESOTA_TWINS': 'MIN',
    'NEW_YORK_METS': 'NYM',
    'NEW_YORK_YANKEES': 'NYY',
    'OAKLAND_ATHLETICS': 'ATH',
    'PHILADELPHIA_PHILLIES': 'PHI',
    'PITTSBURGH_PIRATES': 'PIT',
    'SAN_DIEGO_PADRES': 'SDP',
    'SAN_FRANCISCO_GIANTS': 'SFG',
    'SEATTLE_MARINERS': 'SEA',
    'STLOUIS_CARDINALS': 'STL',
    'TAMPA_BAY_RAYS': 'TBR',
    'TEXAS_RANGERS': 'TEX',
    'TORONTO_BLUE_JAYS': 'TOR',
    'WASHINGTON_NATIONALS': 'WSH'}


# Apply the mapping
df_odds.loc[:, 'team_1'] = df_odds['team_1'].map(team_mapping)
df_odds.loc[:, 'team_2'] = df_odds['team_2'].map(team_mapping)

# %%
#making the line collumn an integer
df_odds['overUnder'] = pd.to_numeric(df_odds['overUnder'], errors='coerce')

# %%
df_odds['bet']='RBI'

# %%
df_odds=df_odds[['player','side','overUnder','bookmaker','odds','sport','team_1','team_2','bet']]

# %%
# Merge on the 'player' column
df_odds = df_odds.merge(
    batter_team_2025[['player', 'team']],
    on='player',
    how='left'
)

# %%
df_odds.dropna()
# Out:
#             player   side  overUnder    bookmaker  odds sport team_1 team_2  \
# 0      Aaron Judge   over        0.5   draftkings  -105   MLB    NYM    NYY
# 1      Aaron Judge   over        0.5      espnbet  +100   MLB    NYM    NYY
# 2      Aaron Judge   over        0.5  hardrockbet  +100   MLB    NYM    NYY
# 3      Aaron Judge   over        0.5        fliff  -105   MLB    NYM    NYY
# 4      Aaron Judge   over        0.5      fanduel  -120   MLB    NYM    NYY
# ...            ...    ...        ...          ...   ...   ...    ...    ...
# 3675  Chris Taylor  under        0.5      espnbet  -425   MLB    LAA    LAD
# 3676  Chris Taylor  under        0.5   draftkings  -390   MLB    LAA    LAD
# 3677  Chris Taylor  under        0.5        fliff  -400   MLB    LAA    LAD
# 3678  Chris Taylor  under        0.5  hardrockbet  -400   MLB    LAA    LAD
# 3679  Chris Taylor  under        0.5       betmgm  -375   MLB    LAA    LAD
#
#       bet team
# 0     RBI  NYY
# 1     RBI  NYY
# 2     RBI  NYY
# 3     RBI  NYY
# 4     RBI  NYY
# ...   ...  ...
# 3675  RBI  LAD
# 3676  RBI  LAD
# 3677  RBI  LAD
# 3678  RBI  LAD
# 3679  RBI  LAD
#
# [3433 rows x 10 columns]

# %%
# Step 1: Identify the "odd one out" team to find the defensive team
df_odds['def_team'] = df_odds.apply(lambda row: row['team_2'] if row['team'] == row['team_1'] else row['team_1'], axis=1)

# %%
df_odds.dropna()
# Out:
#             player   side  overUnder    bookmaker  odds sport team_1 team_2  \
# 0      Aaron Judge   over        0.5   draftkings  -105   MLB    NYM    NYY
# 1      Aaron Judge   over        0.5      espnbet  +100   MLB    NYM    NYY
# 2      Aaron Judge   over        0.5  hardrockbet  +100   MLB    NYM    NYY
# 3      Aaron Judge   over        0.5        fliff  -105   MLB    NYM    NYY
# 4      Aaron Judge   over        0.5      fanduel  -120   MLB    NYM    NYY
# ...            ...    ...        ...          ...   ...   ...    ...    ...
# 3675  Chris Taylor  under        0.5      espnbet  -425   MLB    LAA    LAD
# 3676  Chris Taylor  under        0.5   draftkings  -390   MLB    LAA    LAD
# 3677  Chris Taylor  under        0.5        fliff  -400   MLB    LAA    LAD
# 3678  Chris Taylor  under        0.5  hardrockbet  -400   MLB    LAA    LAD
# 3679  Chris Taylor  under        0.5       betmgm  -375   MLB    LAA    LAD
#
#       bet team def_team
# 0     RBI  NYY      NYM
# 1     RBI  NYY      NYM
# 2     RBI  NYY      NYM
# 3     RBI  NYY      NYM
# 4     RBI  NYY      NYM
# ...   ...  ...      ...
# 3675  RBI  LAD      LAA
# 3676  RBI  LAD      LAA
# 3677  RBI  LAD      LAA
# 3678  RBI  LAD      LAA
# 3679  RBI  LAD      LAA
#
# [3433 rows x 11 columns]

# %%
#drop redundant collumns that are useless
df_odds = df_odds.drop(columns=['team_1', 'team_2'], errors='ignore')

# %%
# Rename the team column before merging (if needed)
def_rank = def_rank.rename(columns={"team": "def_team"})

# %%
# Merge on the 'player' column
df_odds = df_odds.merge(def_rank, on='def_team', how='left')
df_odds.dropna()
# Out:
#             player   side  overUnder    bookmaker  odds sport  bet team  \
# 0      Aaron Judge   over        0.5   draftkings  -105   MLB  RBI  NYY
# 1      Aaron Judge   over        0.5      espnbet  +100   MLB  RBI  NYY
# 2      Aaron Judge   over        0.5  hardrockbet  +100   MLB  RBI  NYY
# 3      Aaron Judge   over        0.5        fliff  -105   MLB  RBI  NYY
# 4      Aaron Judge   over        0.5      fanduel  -120   MLB  RBI  NYY
# ...            ...    ...        ...          ...   ...   ...  ...  ...
# 3675  Chris Taylor  under        0.5      espnbet  -425   MLB  RBI  LAD
# 3676  Chris Taylor  under        0.5   draftkings  -390   MLB  RBI  LAD
# 3677  Chris Taylor  under        0.5        fliff  -400   MLB  RBI  LAD
# 3678  Chris Taylor  under        0.5  hardrockbet  -400   MLB  RBI  LAD
# 3679  Chris Taylor  under        0.5       betmgm  -375   MLB  RBI  LAD
#
#      def_team  Unnamed: 0  def_rank
# 0         NYM           0         1
# 1         NYM           0         1
# 2         NYM           0         1
# 3         NYM           0         1
# 4         NYM           0         1
# ...       ...         ...       ...
# 3675      LAA          25        25
# 3676      LAA          25        25
# 3677      LAA          25        25
# 3678      LAA          25        25
# 3679      LAA          25        25
#
# [3433 rows x 11 columns]

# %%
#making game collumn
df_odds['game'] = df_odds['team'] + ' vs ' + df_odds['def_team']

# %%
df_odds2=df_odds.dropna()

# %%
df_odds3 = df_odds2.drop(columns=['team', 'def_team'])

# %%
df_odds3
# Out:
#             player   side  overUnder    bookmaker  odds sport  bet  \
# 0      Aaron Judge   over        0.5   draftkings  -105   MLB  RBI
# 1      Aaron Judge   over        0.5      espnbet  +100   MLB  RBI
# 2      Aaron Judge   over        0.5  hardrockbet  +100   MLB  RBI
# 3      Aaron Judge   over        0.5        fliff  -105   MLB  RBI
# 4      Aaron Judge   over        0.5      fanduel  -120   MLB  RBI
# ...            ...    ...        ...          ...   ...   ...  ...
# 3675  Chris Taylor  under        0.5      espnbet  -425   MLB  RBI
# 3676  Chris Taylor  under        0.5   draftkings  -390   MLB  RBI
# 3677  Chris Taylor  under        0.5        fliff  -400   MLB  RBI
# 3678  Chris Taylor  under        0.5  hardrockbet  -400   MLB  RBI
# 3679  Chris Taylor  under        0.5       betmgm  -375   MLB  RBI
#
#       Unnamed: 0  def_rank        game
# 0              0         1  NYY vs NYM
# 1              0         1  NYY vs NYM
# 2              0         1  NYY vs NYM
# 3              0         1  NYY vs NYM
# 4              0         1  NYY vs NYM
# ...          ...       ...         ...
# 3675          25        25  LAD vs LAA
# 3676          25        25  LAD vs LAA
# 3677          25        25  LAD vs LAA
# 3678          25        25  LAD vs LAA
# 3679          25        25  LAD vs LAA
#
# [3433 rows x 10 columns]

# %%
overs = df_odds3[(df_odds3['side'].str.lower() == 'over') & (df_odds3['def_rank'] > 15)]
unders = df_odds3[(df_odds3['side'].str.lower() == 'under') & (df_odds3['def_rank'] < 16)]

# %%
overs = overs.merge(over_rbi_rate, on='player', how='left')
unders = unders.merge(under_rbi_rate, on='player', how='left')

# %%
overs_2=overs.dropna()
unders_2=unders.dropna()

# %%
#making odds collumn numeric
unders_2['odds'] = pd.to_numeric(unders_2['odds'], errors='coerce')
overs_2['odds'] = pd.to_numeric(overs_2['odds'], errors='coerce')
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\2110421890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unders_2['odds'] = pd.to_numeric(unders_2['odds'], errors='coerce')
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\2110421890.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overs_2['odds'] = pd.to_numeric(overs_2['odds'], errors='coerce')

# %%
#making decimal odds
unders_2['decimal_odds'] = unders_2['odds'].apply(
    lambda x: (x / 100) + 1 if x > 0 else (100 / abs(x)) + 1
)
overs_2['decimal_odds'] = overs_2['odds'].apply(
    lambda x: (x / 100) + 1 if x > 0 else (100 / abs(x)) + 1
)
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\875580270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unders_2['decimal_odds'] = unders_2['odds'].apply(
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\875580270.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overs_2['decimal_odds'] = overs_2['odds'].apply(

# %%
#making profit
overs_2['profit'] = (overs_2['decimal_odds'] * 100) - 100
unders_2['profit'] = (unders_2['decimal_odds'] * 100) - 100
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\3093691362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overs_2['profit'] = (overs_2['decimal_odds'] * 100) - 100
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\3093691362.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unders_2['profit'] = (unders_2['decimal_odds'] * 100) - 100

# %%
def calculate_ev(row):
    if row['overUnder'] == 0.5:
        rate = row['1_RBI_rate_over']
    elif row['overUnder'] == 1.5:
        rate = row['2_RBI_rate_over']
    elif row['overUnder'] == 2.5:
        rate = row['3_RBI_rate_over']
    elif row['overUnder'] == 3.5:
        rate = row['4_RBI_rate_over']
    else:
        return None  # or np.nan, if you want to leave it blank for other lines

    # Expected Value formula
    return (rate * row['profit']) - ((1 - rate) * 100)

# Apply the formula to each row
overs_2['edge'] = overs_2.apply(calculate_ev, axis=1)
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\882109118.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overs_2['edge'] = overs_2.apply(calculate_ev, axis=1)

# %%
#edge for unders
def calculate_under_ev(row):
    if row['overUnder'] == 0.5:
        rate = row['1_RBI_rate_under']
    elif row['overUnder'] == 1.5:
        rate = row['2_RBI_rate_under']
    elif row['overUnder'] == 2.5:
        rate = row['3_RBI_rate_under']
    elif row['overUnder'] == 3.5:
        rate = row['4_RBI_rate_under']
    else:
        return None  # or np.nan for unsupported lines

    return ((1 - rate) * row['profit']) - (rate * 100)

# Apply to each row
unders_2['edge'] = unders_2.apply(calculate_under_ev, axis=1)
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\2277347561.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unders_2['edge'] = unders_2.apply(calculate_under_ev, axis=1)

# %%
overs_2 = overs_2[overs_2['edge'] > 20]

# %%
unders_2 = unders_2[unders_2['edge'] > 20]

# %%
#merging overs_2 on top of unders_2
final_df = pd.concat([overs_2, unders_2], ignore_index=True)

# %%
final_df=final_df[['player','side','overUnder','bookmaker','odds','sport','bet','edge','game']]

# %%
final_df['bet'] = final_df['side'].astype(str) + ' ' + final_df['overUnder'].astype(str) + ' ' + final_df['bet'].astype(str)

# %%
final_df = final_df.rename(columns={'bookmaker': 'book'})

# %%
final_df['edge'] = final_df['edge'] / 2

# %%
final_df['edge'] = final_df['edge'].round(1)

# %%
final_df=final_df[['book','sport','player','game','bet','odds','edge']]

# %%
final_df = final_df.sort_values(by='edge', ascending=False).reset_index(drop=True)

# %%
# #changing book names
# team_mapping_3 = {
#     'betonline': 'BetOnline',
#     'bovada': 'Bovada',
#     'fanatics': 'Fanatics',
#     'hardrockbet': 'Hard Rock Bet',
#     'sporttrade': 'Sporttrade',
#     'balleybet': 'Balley Bet',
#     'betmgm': 'BetMGM',
#     'draftkings': 'DraftKings',
#     'ceasers': 'Ceasers',
#     'fanduel': 'FanDuel',
#     'fliff': 'Fliff',
#     'espnbet': 'ESPNBET',
#     'betrivers': 'BetRivers'
# }

# final_df['book'] = final_df['book'].map(team_mapping_3)

# %%
#putting + in front of the ones that dont have it
final_df['odds'] = final_df['odds'].apply(lambda x: f"+{x}" if x > 0 else str(x))

final_df
# Out:
#             book sport             player        game            bet  odds  \
# 0      betrivers   MLB  Michael A. Taylor  CHW vs CHC   over 0.5 RBI  +320
# 1       ballybet   MLB  Michael A. Taylor  CHW vs CHC   over 0.5 RBI  +320
# 2       fanatics   MLB  Michael A. Taylor  CHW vs CHC   over 0.5 RBI  +300
# 3        fanduel   MLB  Michael A. Taylor  CHW vs CHC   over 0.5 RBI  +300
# 4    hardrockbet   MLB  Michael A. Taylor  CHW vs CHC   over 0.5 RBI  +300
# ..           ...   ...                ...         ...            ...   ...
# 329      espnbet   MLB        Jose Altuve  HOU vs TEX  under 0.5 RBI  -325
# 330   draftkings   MLB       Brent Rooker  ATH vs SFG  under 0.5 RBI  -230
# 331        fliff   MLB       Brent Rooker  ATH vs SFG  under 0.5 RBI  -230
# 332      espnbet   MLB      Austin Hedges  CLE vs CIN  under 0.5 RBI  -450
# 333      espnbet   MLB          Juan Soto  NYM vs NYY  under 0.5 RBI  -220
#
#       edge
# 0    104.3
# 1    104.3
# 2     97.0
# 3     97.0
# 4     97.0
# ..     ...
# 329   10.2
# 330   10.2
# 331   10.2
# 332   10.1
# 333   10.1
#
# [334 rows x 7 columns]

# %%
# # Convert DataFrame to JSON (Python list of dicts)
# data_json = json.loads(final_df.to_json(orient="records"))

# # Endpoint URL
# url = "https://pitstoppicks.com/wp-json/custom-api/v1/mlb_batter_total_RBI"

# # Make sure this is your FULL WordPress login email (not just 'josheskragmailcom')
# username = "josheskra@gmail.com"

# # This must be your app password EXACTLY as shown when created — include all spaces
# password = "BFgx z2iv nW9I voXn 1X51 fjRq"

# # Headers
# headers = {
#     "Content-Type": "application/json"
# }

# # POST request
# response = requests.post(
#     url,
#     headers=headers,
#     auth=HTTPBasicAuth(username, password),
#     json=data_json
# )

# # Debug
# print("Status Code:", response.status_code)
# print("Response Text:", response.text)

# %%
import json
import requests

# Convert your DataFrame to JSON
data_json = json.loads(final_df.to_json(orient="records"))

# Endpoint URL
url = "https://pitstoppicks.com/wp-json/custom-api/v1/mlb_batter_RBI"

# Headers
headers = {
    "Content-Type": "application/json"
}

# Send the POST request without authentication
response = requests.post(url, headers=headers, json=data_json)

# Debugging output
print("Status Code:", response.status_code)
print("Response Text:", response.text)
# Out:
# Status Code: 200
# Response Text: {"message":"Data received","data":[{"book":"betrivers","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+320","edge":104.3},{"book":"ballybet","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+320","edge":104.3},{"book":"fanatics","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+300","edge":97},{"book":"fanduel","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+300","edge":97},{"book":"hardrockbet","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+300","edge":97},{"book":"draftkings","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+290","edge":93.3},{"book":"betmgm","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+290","edge":93.3},{"book":"betrivers","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+225","edge":87.2},{"book":"ballybet","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+225","edge":87.2},{"book":"espnbet","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+270","edge":86},{"book":"hardrockbet","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+220","edge":85.1},{"book":"betmgm","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+220","edge":85.1},{"book":"fanduel","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+220","edge":85.1},{"book":"draftkings","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+215","edge":83},{"book":"fliff","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+210","edge":80.9},{"book":"fanatics","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+210","edge":80.9},{"book":"espnbet","sport":"MLB","player":"Justyn-Henry Malloy","game":"DET vs TOR","bet":"over 0.5 RBI","odds":"+210","edge":80.9},{"book":"fliff","sport":"MLB","player":"Michael A. Taylor","game":"CHW vs CHC","bet":"over 0.5 RBI","odds":"+255","edge":80.5},{"book":"betmgm","sport":"MLB","player":"Geraldo Perdomo","game":"ARI vs COL","bet":"over 0.5 RBI","odds":"+190","edge":70.8},{"book":"draftkings","sport":"MLB","player":"Geraldo Perdomo","game":"ARI vs COL","bet":"over 0.5 RBI","odds":"+185","edge":68.8},{"book":"hardrockbet","sport":"MLB","player":"Geraldo Perdomo","game":"ARI vs COL","bet":"over 0.5 RBI","odds":"+185","edge":68.8},{"book":"fanatics","sport":"MLB","player":"Geraldo Perdomo","game":"ARI vs COL","bet":"over 0.5 RBI","odds":"+185","edge":68.8},{"book":"espnbet","sport":"MLB","player":"Geraldo Perdomo","game":"ARI vs COL","bet":"over 0.5 RBI","odds":"+180","edge":66.7},{"book":"fanduel","sport":"MLB","player":"Geraldo Perdomo","game":"ARI vs COL","bet":"over 0.5 RBI","odds":"+175","edge":64.6},{"book":"ballybet","sport":"MLB","player":"Heliot Ramos","game":"SFG vs ATH","bet":"over 0.5 RBI","odds":"+170","edge":64.1},{"book":"betrivers","sport":"MLB","player":"Heliot Ramos","game":"SFG vs ATH","bet":"over 0.5 RBI","odds":"+170","edge":64.1},{"book":"betmgm","sport":"MLB","player":"Spencer Steer","game":"CIN vs CLE","bet":"over 0.5 RBI","odds":"+190","edge":63.1},{"book":"hardrockbet","sport":"MLB","player":"Kody Clemens","game":"MIN vs MIL","bet":"over 0.5 RBI","odds":"+210","edge":63},{"book":"betmgm","sport":"MLB","player":"Kody Clemens","game":"MIN vs MIL","bet":"over 0.5 RBI","odds":"+210","edge":63},{"book":"fanatics","sport":"MLB","player":"Jose Tena","game":"WSH vs BAL","bet":"over 0.5 RBI","odds":"+170","edge":62.7},{"book":"fanduel","sport":"MLB","player":"Jose Tena","game":"WSH vs BAL","bet":"over 0.5  ...

# %%
# # Convert DataFrame to JSON (ensure it's a Python list, not a string)
# data_json = json.loads(final_df.to_json(orient="records"))  # ✅ Converts string to Python object

# # WordPress API URL
# url = "https://pitstoppicks.com/wp-json/custom-api/v1/mlb_batter_RBI"

# # Authentication
# # auth = HTTPBasicAuth("josheskragmailcom", "v!(d$mQZnAxSqek!1iAD$d!Q")
# auth = HTTPBasicAuth("josheskragmailcom", "UhiM WLwm dEOK T171 RUkT Sw2F")
# # Headers
# headers = {
#     "Content-Type": "application/json"
# }

# # Send POST request (requests will handle JSON encoding automatically)
# response = requests.post(url, headers=headers, auth=auth, json=data_json)  # ✅ FIX: Use json= instead of data=

# # Debugging Output
# print("Status Code:", response.status_code)
# print("Response Text:", response.text)

# %%
#YOU CAN DELETE ALL OF THIS THIS IS FOR WHEN I KEEP TRACK OF THE BETS LOCALLY

# %%
# Step 1: Sort to ensure reproducibility in tie cases
df_sorted = final_df.sort_values('edge')

# Step 2: Define a function to get the row with median edge for each group
def get_median_row(group):
    median_edge = group['edge'].median()
    # Get the row closest to the median (or first in case of exact match/ties)
    return group.iloc[(group['edge'] - median_edge).abs().argsort().iloc[0]]

# Step 3: Apply it to each group
df_filtered = df_sorted.groupby(['player', 'game', 'bet'], group_keys=False).apply(get_median_row)

# Step 4: Reset index if needed
df_filtered.reset_index(drop=True, inplace=True)
df_filtered
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_147632\1266780210.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_filtered = df_sorted.groupby(['player', 'game', 'bet'], group_keys=False).apply(get_median_row)
#            book sport               player        game            bet  odds  \
# 0   hardrockbet   MLB       Addison Barger  TOR vs DET  under 0.5 RBI  -230
# 1        betmgm   MLB            Alec Bohm  PHI vs PIT   over 0.5 RBI  +170
# 2        betmgm   MLB     Andrew McCutchen  PIT vs PHI  under 0.5 RBI  -275
# 3   hardrockbet   MLB        Andrew Vaughn  CHW vs CHC   over 0.5 RBI  +150
# 4   hardrockbet   MLB    Anthony Santander  TOR vs DET  under 0.5 RBI  -180
# 5    draftkings   MLB          Austin Hays  CIN vs CLE   over 0.5 RBI  +120
# 6    draftkings   MLB        Austin Hedges  CLE vs CIN  under 0.5 RBI  -425
# 7        betmgm   MLB         Austin Wells  NYY vs NYM  under 0.5 RBI  -200
# 8    draftkings   MLB             Ben Rice  NYY vs NYM  under 0.5 RBI  -240
# 9   hardrockbet   MLB         Brent Rooker  ATH vs SFG  under 0.5 RBI  -220
# 10     ballybet   MLB           Brooks Lee  MIN vs MIL   over 0.5 RBI  +195
# 11  hardrockbet   MLB       Bryan Reynolds  PIT vs PHI  under 0.5 RBI  -260
# 12   draftkings   MLB         Bryson Stott  PHI vs PIT   over 0.5 RBI  +180
# 13        fliff   MLB          Cal Raleigh  SEA vs SDP  under 0.5 RBI  -220
# 14       betmgm   MLB       Carlos Santana  CLE vs CIN  under 0.5 RBI  -155
# 15      espnbet   MLB     Christian Walker  HOU vs TEX  under 0.5 RBI  -200
# 16       betmgm   MLB     Christian Yelich  MIL vs MIN  under 0.5 RBI  -275
# 17      espnbet   MLB       Cody Bellinger  NYY vs NYM  under 0.5 RBI  -220
# 18  hardrockbet   MLB          Connor Wong  BOS vs ATL  under 0.5 RBI  -230
# 19      espnbet   MLB       Daulton Varsho  TOR vs DET  under 0.5 RBI  -225
# 20   prizepicks   MLB       Eugenio Suarez  ARI vs COL   over 0.5 RBI  +100
# 21  hardrockbet   MLB     Francisco Lindor  NYM vs NYY  under 0.5 RBI  -225
# 22   draftkings   MLB        Freddy Fermin  KCR vs STL  under 0.5 RBI  -295
# 23       betmgm   MLB        Gabriel Arias  CLE vs CIN  under 0.5 RBI  -250
# 24   draftkings   MLB         Gavin Sheets  SDP vs SEA  under 0.5 RBI  -265
# 25  hardrockbet   MLB      George Springer  TOR vs DET  under 0.5 RBI  -240
# 26   draftkings   MLB      Geraldo Perdomo  ARI vs COL   over 0.5 RBI  +185
# 27     ballybet   MLB     Gunnar Henderson  BAL vs WSH   over 0.5 RBI  +116
# 28   draftkings   MLB         Heliot Ramos  SFG vs ATH   over 0.5 RBI  +160
# 29      fanduel   MLB        J.T. Realmuto  PHI vs PIT   over 0.5 RBI  +165
# 30        fliff   MLB      Jackson Chourio  MIL vs MIN  under 0.5 RBI  -265
# 31      espnbet   MLB      Jackson Merrill  SDP vs SEA  under 0.5 RBI  -155
# 32       betmgm   MLB          Jake Meyers  HOU vs TEX  under 0.5 RBI  -300
# 33      espnbet   MLB       Jhonkensy Noel  CLE vs CIN  under 0.5 RBI  -240
# 34       betmgm   MLB            Joey Bart  PIT vs PHI  under 0.5 RBI  -275
# 35   draftkings   MLB          Jose Altuve  HOU vs TEX  under 0.5 RBI  -310
# 36       betmgm   MLB            Jose Tena  WSH vs BAL   over 0.5 RBI  +165
# 37   draftkings   MLB            Juan Soto  NYM vs NYY  under 0.5 RBI  -215
# 38      fanduel   MLB  Justyn-Henry Malloy  DET vs TOR   over 0.5 RBI  +220
# 39      fanduel   MLB          Ketel Marte  ARI vs COL   over 0.5 RBI  +105
# 40      espnbet   MLB         Kody Clemens  MIN vs MIL   over 0.5 RBI  +200
# 41       betmgm   MLB      Lawrence Butler  ATH vs SFG  under 0.5 RBI  -275
# 42    betrivers   MLB           Max Kepler  PHI vs PIT   over 0.5 RBI  +155
# 43  hardrockbet   MLB    Michael A. Taylor  CHW vs CHC   over 0.5 RBI  +300
# 44      espnbet   MLB          Pedro Pages  STL vs KCR  under 0.5 RBI  -275
# 45  hardrockbet   MLB      Randy Arozarena  SEA vs SDP  under 0.5 RBI  -260
# 46     fanatics   MLB         Riley Greene  DET vs TOR   over 0.5 RBI  +150
# 47  hardrockbet   MLB       Salvador Perez  KCR vs STL  under 0.5 RBI  -190
# 48      espnbet   MLB      Shea Langeliers  ATH vs SFG  under 0.5 RBI  -220
# 49    betrivers   MLB        Spencer Steer  CIN vs CLE   over 0.5 RBI  +180
# 50   draftkings   MLB          Steven Kwan  CLE vs CIN  under 0.5 RBI  -290
# 51   draftkings   MLB            TJ Friedl  CIN vs CLE   over 0.5 RBI  +215
# 52      espnbet   MLB        Trent Grisham  NYY vs NYM  under 0.5 RBI  -240
# 53  hardrockbet   MLB      Victor Caratini  HOU vs TEX  under 0.5 RBI  -325
# 54  hardrockbet   MLB      Victor Scott II  STL vs KCR  under 0.5 RBI  -400
# 55      espnbet   MLB    Willson Contreras  STL vs KCR  under 0.5 RBI  -240
# 56  hardrockbet   MLB         Wilyer Abreu  BOS vs ATL  under 0.5 RBI  -165
#
#     edge
# 0   16.8
# 1   15.2
# 2   11.5
# 3   48.3
# 4   19.8
# 5   35.8
# 6   10.7
# 7   17.9
# 8   17.1
# 9   11.0
# 10  51.3
# 11  11.7
# 12  15.0
# 13  14.2
# 14  25.0
# 15  16.6
# 16  12.3
# 17  15.1
# 18  16.9
# 19  17.3
# 20  29.6
# 21  14.8
# 22  11.9
# 23  18.1
# 24  13.3
# 25  15.5
# 26  68.8
# 27  46.0
# 28  59.9
# 29  10.9
# 30  13.6
# 31  23.5
# 32  10.8
# 33  16.8
# 34  12.9
# 35  10.9
# 36  60.6
# 37  10.5
# 38  85.1
# 39  36.3
# 40  59.4
# 41  12.7
# 42  11.1
# 43  97.0
# 44  15.0
# 45  12.7
# 46  49.4
# 47  16.7
# 48  13.5
# 49  59.2
# 50  11.3
# 51  13.0
# 52  17.5
# 53  12.2
# 54  11.3
# 55  10.3
# 56  20.8

# %%
# Make sure odds column is numeric
df_filtered['odds'] = pd.to_numeric(df_filtered['odds'], errors='coerce')
# Convert American odds to decimal odds
def american_to_decimal(odds):
    if pd.isna(odds):
        return None
    if odds > 0:
        return round((odds / 100) + 1, 3)
    else:
        return round((100 / abs(odds)) + 1, 3)

# Apply conversion
df_filtered['decimal_odds'] = df_filtered['odds'].apply(american_to_decimal)

# Check it out
print(df_filtered[['odds', 'decimal_odds']].head())
# Out:
#    odds  decimal_odds
# 0  -230         1.435
# 1   170         2.700
# 2  -275         1.364
# 3   150         2.500
# 4  -180         1.556

# %%
df_filtered['profit'] = (df_filtered['decimal_odds'] * 100) - 100
df_filtered
# Out:
#            book sport               player        game            bet  odds  \
# 0   hardrockbet   MLB       Addison Barger  TOR vs DET  under 0.5 RBI  -230
# 1        betmgm   MLB            Alec Bohm  PHI vs PIT   over 0.5 RBI   170
# 2        betmgm   MLB     Andrew McCutchen  PIT vs PHI  under 0.5 RBI  -275
# 3   hardrockbet   MLB        Andrew Vaughn  CHW vs CHC   over 0.5 RBI   150
# 4   hardrockbet   MLB    Anthony Santander  TOR vs DET  under 0.5 RBI  -180
# 5    draftkings   MLB          Austin Hays  CIN vs CLE   over 0.5 RBI   120
# 6    draftkings   MLB        Austin Hedges  CLE vs CIN  under 0.5 RBI  -425
# 7        betmgm   MLB         Austin Wells  NYY vs NYM  under 0.5 RBI  -200
# 8    draftkings   MLB             Ben Rice  NYY vs NYM  under 0.5 RBI  -240
# 9   hardrockbet   MLB         Brent Rooker  ATH vs SFG  under 0.5 RBI  -220
# 10     ballybet   MLB           Brooks Lee  MIN vs MIL   over 0.5 RBI   195
# 11  hardrockbet   MLB       Bryan Reynolds  PIT vs PHI  under 0.5 RBI  -260
# 12   draftkings   MLB         Bryson Stott  PHI vs PIT   over 0.5 RBI   180
# 13        fliff   MLB          Cal Raleigh  SEA vs SDP  under 0.5 RBI  -220
# 14       betmgm   MLB       Carlos Santana  CLE vs CIN  under 0.5 RBI  -155
# 15      espnbet   MLB     Christian Walker  HOU vs TEX  under 0.5 RBI  -200
# 16       betmgm   MLB     Christian Yelich  MIL vs MIN  under 0.5 RBI  -275
# 17      espnbet   MLB       Cody Bellinger  NYY vs NYM  under 0.5 RBI  -220
# 18  hardrockbet   MLB          Connor Wong  BOS vs ATL  under 0.5 RBI  -230
# 19      espnbet   MLB       Daulton Varsho  TOR vs DET  under 0.5 RBI  -225
# 20   prizepicks   MLB       Eugenio Suarez  ARI vs COL   over 0.5 RBI   100
# 21  hardrockbet   MLB     Francisco Lindor  NYM vs NYY  under 0.5 RBI  -225
# 22   draftkings   MLB        Freddy Fermin  KCR vs STL  under 0.5 RBI  -295
# 23       betmgm   MLB        Gabriel Arias  CLE vs CIN  under 0.5 RBI  -250
# 24   draftkings   MLB         Gavin Sheets  SDP vs SEA  under 0.5 RBI  -265
# 25  hardrockbet   MLB      George Springer  TOR vs DET  under 0.5 RBI  -240
# 26   draftkings   MLB      Geraldo Perdomo  ARI vs COL   over 0.5 RBI   185
# 27     ballybet   MLB     Gunnar Henderson  BAL vs WSH   over 0.5 RBI   116
# 28   draftkings   MLB         Heliot Ramos  SFG vs ATH   over 0.5 RBI   160
# 29      fanduel   MLB        J.T. Realmuto  PHI vs PIT   over 0.5 RBI   165
# 30        fliff   MLB      Jackson Chourio  MIL vs MIN  under 0.5 RBI  -265
# 31      espnbet   MLB      Jackson Merrill  SDP vs SEA  under 0.5 RBI  -155
# 32       betmgm   MLB          Jake Meyers  HOU vs TEX  under 0.5 RBI  -300
# 33      espnbet   MLB       Jhonkensy Noel  CLE vs CIN  under 0.5 RBI  -240
# 34       betmgm   MLB            Joey Bart  PIT vs PHI  under 0.5 RBI  -275
# 35   draftkings   MLB          Jose Altuve  HOU vs TEX  under 0.5 RBI  -310
# 36       betmgm   MLB            Jose Tena  WSH vs BAL   over 0.5 RBI   165
# 37   draftkings   MLB            Juan Soto  NYM vs NYY  under 0.5 RBI  -215
# 38      fanduel   MLB  Justyn-Henry Malloy  DET vs TOR   over 0.5 RBI   220
# 39      fanduel   MLB          Ketel Marte  ARI vs COL   over 0.5 RBI   105
# 40      espnbet   MLB         Kody Clemens  MIN vs MIL   over 0.5 RBI   200
# 41       betmgm   MLB      Lawrence Butler  ATH vs SFG  under 0.5 RBI  -275
# 42    betrivers   MLB           Max Kepler  PHI vs PIT   over 0.5 RBI   155
# 43  hardrockbet   MLB    Michael A. Taylor  CHW vs CHC   over 0.5 RBI   300
# 44      espnbet   MLB          Pedro Pages  STL vs KCR  under 0.5 RBI  -275
# 45  hardrockbet   MLB      Randy Arozarena  SEA vs SDP  under 0.5 RBI  -260
# 46     fanatics   MLB         Riley Greene  DET vs TOR   over 0.5 RBI   150
# 47  hardrockbet   MLB       Salvador Perez  KCR vs STL  under 0.5 RBI  -190
# 48      espnbet   MLB      Shea Langeliers  ATH vs SFG  under 0.5 RBI  -220
# 49    betrivers   MLB        Spencer Steer  CIN vs CLE   over 0.5 RBI   180
# 50   draftkings   MLB          Steven Kwan  CLE vs CIN  under 0.5 RBI  -290
# 51   draftkings   MLB            TJ Friedl  CIN vs CLE   over 0.5 RBI   215
# 52      espnbet   MLB        Trent Grisham  NYY vs NYM  under 0.5 RBI  -240
# 53  hardrockbet   MLB      Victor Caratini  HOU vs TEX  under 0.5 RBI  -325
# 54  hardrockbet   MLB      Victor Scott II  STL vs KCR  under 0.5 RBI  -400
# 55      espnbet   MLB    Willson Contreras  STL vs KCR  under 0.5 RBI  -240
# 56  hardrockbet   MLB         Wilyer Abreu  BOS vs ATL  under 0.5 RBI  -165
#
#     edge  decimal_odds  profit
# 0   16.8         1.435    43.5
# 1   15.2         2.700   170.0
# 2   11.5         1.364    36.4
# 3   48.3         2.500   150.0
# 4   19.8         1.556    55.6
# 5   35.8         2.200   120.0
# 6   10.7         1.235    23.5
# 7   17.9         1.500    50.0
# 8   17.1         1.417    41.7
# 9   11.0         1.455    45.5
# 10  51.3         2.950   195.0
# 11  11.7         1.385    38.5
# 12  15.0         2.800   180.0
# 13  14.2         1.455    45.5
# 14  25.0         1.645    64.5
# 15  16.6         1.500    50.0
# 16  12.3         1.364    36.4
# 17  15.1         1.455    45.5
# 18  16.9         1.435    43.5
# 19  17.3         1.444    44.4
# 20  29.6         2.000   100.0
# 21  14.8         1.444    44.4
# 22  11.9         1.339    33.9
# 23  18.1         1.400    40.0
# 24  13.3         1.377    37.7
# 25  15.5         1.417    41.7
# 26  68.8         2.850   185.0
# 27  46.0         2.160   116.0
# 28  59.9         2.600   160.0
# 29  10.9         2.650   165.0
# 30  13.6         1.377    37.7
# 31  23.5         1.645    64.5
# 32  10.8         1.333    33.3
# 33  16.8         1.417    41.7
# 34  12.9         1.364    36.4
# 35  10.9         1.323    32.3
# 36  60.6         2.650   165.0
# 37  10.5         1.465    46.5
# 38  85.1         3.200   220.0
# 39  36.3         2.050   105.0
# 40  59.4         3.000   200.0
# 41  12.7         1.364    36.4
# 42  11.1         2.550   155.0
# 43  97.0         4.000   300.0
# 44  15.0         1.364    36.4
# 45  12.7         1.385    38.5
# 46  49.4         2.500   150.0
# 47  16.7         1.526    52.6
# 48  13.5         1.455    45.5
# 49  59.2         2.800   180.0
# 50  11.3         1.345    34.5
# 51  13.0         3.150   215.0
# 52  17.5         1.417    41.7
# 53  12.2         1.308    30.8
# 54  11.3         1.250    25.0
# 55  10.3         1.417    41.7
# 56  20.8         1.606    60.6

# %%
df_filtered.to_csv('median_rbi_bets.csv')
