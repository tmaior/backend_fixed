# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# Replace with your actual database info
host = 'h40d45593501225.db.45593501.809.hostedresource.net'
user = 'h40d45593501225'
password = 'z)/lKR|eSx6X'
database = 'h40d45593501225'
db_port = '3310'       # only include if DB_HOST has a port in it

# SQLAlchemy connection string (with port)
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{db_port}/{database}')

# %%
# List tables to confirm the connection
pd.read_sql("SHOW TABLES;", engine)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\envs\dev\Lib\site-packages\pymysql\connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File C:\ProgramData\anaconda3\envs\dev\Lib\socket.py:853, in create_connection(address, timeout, source_address, all_errors)
#     852 if not all_errors:
# --> 853     raise exceptions[0]
#     854 raise ExceptionGroup("create_connection failed", exceptions)
#
# File C:\ProgramData\anaconda3\envs\dev\Lib\socket.py:838, in create_connection(address, timeout, source_address, all_errors)
#     837     sock.bind(source_address)
# --> 838 sock.connect(sa)
#     839 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

user     = 'h40d45593501225'
password = 'z)/lKR|eSx6X'
host     = 'h40d45593501225.db.45593501.809.hostedresource.net'
port     = 3310
database = 'h40d45593501225'

engine = create_engine(
    f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
)

df = pd.read_sql("SHOW TABLES;", engine)
print(df)
